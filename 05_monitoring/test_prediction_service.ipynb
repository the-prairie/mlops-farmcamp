# %%
import json
import uuid
from datetime import datetime
from time import sleep

import pyarrow.parquet as pq
import requests

table = pq.read_table("green_tripdata_2022-01.parquet")

data = table.to_pylist()


class DateTimeEncoder(json.JSONEncoder):
    def default(self, o):
        if isinstance(o, datetime):
            return o.isoformat()
        return json.JSONEncoder.default(self, o)

# %%
from pydantic import BaseModel
from typing import Union

# %%
df = pd.read_parquet("green_tripdata_2021-01.parquet")
df.columns = df.columns.str.upper()
df.to_parquet("green_tripdata_2021-01.parquet")

# %%
class Ride(BaseModel):
    VENDORID: str
    LPEP_PICKUP_DATETIME: datetime
    LPEP_DROPOFF_DATETIME: datetime
    STORE_AND_FWD_FLAG: str
    RATECODEID: int
    PULOCATIONID: str
    DOLOCATIONID: str
    PASSENGER_COUNT: int
    TRIP_DISTANCE: float
    FARE_AMOUNT: float
    EXTRA: float
    MTA_TAX: float
    TIP_AMOUNT: float
    TOLLS_AMOUNT: float
    EHAIL_FEE: Union[float, None]
    IMPROVEMENT_SURCHARGE: float
    TOTAL_AMOUNT: float
    PAYMENT_TYPE: int
    TRIP_TYPE: int
    CONGESTION_SURCHARGE: float
    ID: str

# %%
from pymongo import MongoClient

# %%
mongo_client = MongoClient("mongodb://127.0.0.1:27017")
db = mongo_client.get_database("prediction_service")
collection = db.get_collection("data")

# %%
list(collection.find())[-1]
# Out:
# {'_id': ObjectId('62c7249f8c6ba847ae6f943a'),
#  'PULOCATIONID': 7,
#  'DOLOCATIONID': 129,
#  'TRIP_DISTANCE': 3.26,
#  'PU_DO': '7_129',
#  'prediction': 13.566366978374369}

# %%
collection.insert_one({"prediction": 1.023})

# %%
db.list_collections().address
# Out:
# ('127.0.0.1', 27017)

# %%
import pickle
with open("lin_reg.bin", "rb") as f_in:
    dv, model = pickle.load(f_in)
# Out:
# /Users/zar/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DictVectorizer from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/zar/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator LinearRegression from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
def predict(record):
    record["PU_DO"] = str(record["PULOCATIONID"]) + "_" + str(record["DOLOCATIONID"])
    X = dv.transform(record)
    y_pred = model.predict(X)
    
    
    return {
        "duration": y_pred
    }

# %%
for i in data[0:25]:
  row = {key.upper() if type(key) == str else key: value for key, value in i.items()}
  row["ID"] = str(uuid.uuid4())
  req = Ride(**row).json()
  record = json.loads(req)
  print(predict(record))
# Out:
# {'duration': array([5.11869385])}
# {'duration': array([10.20102853])}
# {'duration': array([20.63146117])}
# {'duration': array([6.64319515])}
# {'duration': array([19.88736889])}
# {'duration': array([7.3526372])}
# {'duration': array([26.43757842])}
# {'duration': array([5.14106809])}
# {'duration': array([8.23193295])}
# {'duration': array([26.43757842])}
# {'duration': array([16.53869167])}
# {'duration': array([10.52649735])}
# {'duration': array([6.06953197])}
# {'duration': array([19.36880346])}
# {'duration': array([20.72490798])}
# {'duration': array([8.64865525])}
# {'duration': array([26.41821026])}
# {'duration': array([16.77341692])}
# {'duration': array([12.82696392])}
# {'duration': array([29.47930536])}
# {'duration': array([9.00501793])}
# {'duration': array([9.66328401])}
# {'duration': array([16.68926104])}
# {'duration': array([19.75016234])}
# {'duration': array([26.44129867])}

# %%
# Out:
# {'VENDORID': '2',
#  'LPEP_PICKUP_DATETIME': '2022-01-01T00:14:21',
#  'LPEP_DROPOFF_DATETIME': '2022-01-01T00:15:33',
#  'STORE_AND_FWD_FLAG': 'N',
#  'RATECODEID': 1,
#  'PULOCATIONID': '42',
#  'DOLOCATIONID': '42',
#  'PASSENGER_COUNT': 1,
#  'TRIP_DISTANCE': 0.44,
#  'FARE_AMOUNT': 3.5,
#  'EXTRA': 0.5,
#  'MTA_TAX': 0.5,
#  'TIP_AMOUNT': 0.0,
#  'TOLLS_AMOUNT': 0.0,
#  'EHAIL_FEE': None,
#  'IMPROVEMENT_SURCHARGE': 0.3,
#  'TOTAL_AMOUNT': 4.8,
#  'PAYMENT_TYPE': 2,
#  'TRIP_TYPE': 1,
#  'CONGESTION_SURCHARGE': 0.0,
#  'ID': '81ca1a63-61ff-44e7-8647-2cf6cda4b602'}

# %%
predict(record)
# Out:
# {'duration': array([26.43757842])}

# %%
requests.post("http://127.0.0.1:9696/predict",
                             headers={"Content-Type": "application/json"},
                             data=json.dumps(row, cls=DateTimeEncoder))
# Out:
# <Response [200]>

# %%
requests.post("http://127.0.0.1:9696/predict",
                             headers={"Content-Type": "application/json"},
                             data=json.dumps(row, cls=DateTimeEncoder)).json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# /Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb#ch0000002?line=0'>1</a> requests.post("http://127.0.0.1:9696/predict",
#       <a href='vscode-notebook-cell:/Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb#ch0000002?line=1'>2</a>                              headers={"Content-Type": "application/json"},
#       <a href='vscode-notebook-cell:/Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb#ch0000002?line=2'>3</a>                              data=json.dumps(row, cls=DateTimeEncoder)).json()
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
data[0].upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb#ch0000004?line=0'>1</a> data[0].upper()
#
# AttributeError: 'dict' object has no attribute 'upper'

# %%
with open("target.csv", 'w') as f_target:
    for row in data:
        row['ID'] = str(uuid.uuid4())
        row = {key.upper() if type(key) == str else key: value for key, value in row.items()}
        duration = (row['LPEP_DROPOFF_DATETIME'] - row['LPEP_PICKUP_DATETIME']).total_seconds() / 60
        f_target.write(f"{row['ID']},{duration}\n")
        resp = requests.post("http://127.0.0.1:9696/predict",
                             headers={"Content-Type": "application/json"},
                             data=json.dumps(row, cls=DateTimeEncoder)).json()
        print(f"prediction: {resp}")
        sleep(1)
# Out:
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# prediction: {'ride_duration': 21.578590757985687}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb Cell 14' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb#ch0000001?line=6'>7</a> resp = requests.post("http://127.0.0.1:9696/predict",
#       <a href='vscode-notebook-cell:/Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb#ch0000001?line=7'>8</a>                      headers={"Content-Type": "application/json"},
#       <a href='vscode-notebook-cell:/Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb#ch0000001?line=8'>9</a>                      data=json.dumps(row, cls=DateTimeEncoder)).json()
#      <a href='vscode-notebook-cell:/Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb#ch0000001?line=9'>10</a> print(f"prediction: {resp}")
# ---> <a href='vscode-notebook-cell:/Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb#ch0000001?line=10'>11</a> sleep(1)
#
# KeyboardInterrupt:

# %%
 import pandas as pd
 df = pd.read_parquet(f'https://nyc-tlc.s3.amazonaws.com/trip+data/yellow_tripdata_2021-01.parquet')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb Cell 18' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb#ch0000015?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb#ch0000015?line=1'>2</a> df = pd.read_parquet(f'https://nyc-tlc.s3.amazonaws.com/trip+data/yellow_tripdata_2021-01.parquet')
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/pandas/io/parquet.py:493, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     446 """
#     447 Load a parquet object from the file path, returning a DataFrame.
#     448
#    (...)
#     489 DataFrame
#     490 """
#     491 impl = get_engine(engine)
# --> 493 return impl.read(
#     494     path,
#     495     columns=columns,
#     496     storage_options=storage_options,
#     497     use_nullable_dtypes=use_nullable_dtypes,
#     498     **kwargs,
#     499 )
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/pandas/io/parquet.py:233, in PyArrowImpl.read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     230 if manager == "array":
#     231     to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
# --> 233 path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     234     path,
#     235     kwargs.pop("filesystem", None),
#     236     storage_options=storage_options,
#     237     mode="rb",
#     238 )
#     239 try:
#     240     result = self.api.parquet.read_table(
#     241         path_or_handle, columns=columns, **kwargs
#     242     ).to_pandas(**to_pandas_kwargs)
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/pandas/io/parquet.py:102, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#      92 handles = None
#      93 if (
#      94     not fs
#      95     and not is_dir
#    (...)
#     100     # fsspec resources can also point to directories
#     101     # this branch is used for example when reading from non-fsspec URLs
# --> 102     handles = get_handle(
#     103         path_or_handle, mode, is_text=False, storage_options=storage_options
#     104     )
#     105     fs = None
#     106     path_or_handle = handles.handle
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/pandas/io/common.py:667, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     664     codecs.lookup_error(errors)
#     666 # open URLs
# --> 667 ioargs = _get_filepath_or_buffer(
#     668     path_or_buf,
#     669     encoding=encoding,
#     670     compression=compression,
#     671     mode=mode,
#     672     storage_options=storage_options,
#     673 )
#     675 handle = ioargs.filepath_or_buffer
#     676 handles: list[BaseBuffer]
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/pandas/io/common.py:336, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     334 # assuming storage_options is to be interpreted as headers
#     335 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 336 with urlopen(req_info) as req:
#     337     content_encoding = req.headers.get("Content-Encoding", None)
#     338     if content_encoding == "gzip":
#     339         # Override compression based on Content-Encoding header
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/pandas/io/common.py:236, in urlopen(*args, **kwargs)
#     230 """
#     231 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     232 the stdlib.
#     233 """
#     234 import urllib.request
# --> 236 return urllib.request.urlopen(*args, **kwargs)
#
# File /usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File /usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File /usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File /usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File /usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File /usr/local/Cellar/python@3.9/3.9.13_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/urllib/request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %%
import json
import os
import pickle

import pandas
from prefect import flow, task
from pymongo import MongoClient
import pyarrow.parquet as pq

from evidently import ColumnMapping

from evidently.dashboard import Dashboard
from evidently.dashboard.tabs import DataDriftTab,RegressionPerformanceTab

from evidently.model_profile import Profile
from evidently.model_profile.sections import DataDriftProfileSection, RegressionPerformanceProfileSection

# %%
filename = "target.csv"

# %%
client = MongoClient("mongodb://localhost:27017/")
collection = client.get_database("prediction_service").get_collection("data")
with open(filename) as f_target:
    for line in f_target.readlines():
        row = line.split(",")
        collection.update_one({"_id": row[0]}, {"$set": {"target": float(row[1])}})

# %%
filename = "./evidently_service/datasets/green_tripdata_2021_01.parquet"
MODEL_FILE = os.getenv('MODEL_FILE', './prediction_service/lin_reg.bin')
with open(MODEL_FILE, 'rb') as f_in:
    dv, model = pickle.load(f_in)

reference_data = pq.read_table(filename).to_pandas()
# Create features
reference_data['PU_DO'] = reference_data['PULOCATIONID'].astype(str) + "_" + reference_data['DOLOCATIONID'].astype(str)
# add target column
reference_data['target'] = reference_data["LPEP_DROPOFF_DATETIME"] - reference_data["LPEP_PICKUP_DATETIME"]
reference_data.target = reference_data.target.apply(lambda td: td.total_seconds() / 60)
features = ['PU_DO', 'PULOCATIONID', 'DOLOCATIONID', 'TRIP_DISTANCE']
x_pred = dv.transform(reference_data[features].to_dict(orient='records'))
reference_data['prediction'] = model.predict(x_pred)
# Out:
# /Users/zar/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DictVectorizer from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/zar/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator LinearRegression from version 1.0.2 when using version 1.1.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
reference_data
# Out:
#        VENDORID LPEP_PICKUP_DATETIME LPEP_DROPOFF_DATETIME STORE_AND_FWD_FLAG  \
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
#        RATECODEID  PULOCATIONID  DOLOCATIONID  PASSENGER_COUNT  TRIP_DISTANCE  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 4             2.0           265           265              3.0           0.00
# ...           ...           ...           ...              ...            ...
# 76513         NaN            81            90              NaN          17.63
# 76514         NaN            35           213              NaN          18.36
# 76515         NaN            74            69              NaN           2.50
# 76516         NaN           168           215              NaN          14.48
# 76517         NaN           119           244              NaN           1.81
#
#        FARE_AMOUNT  ...  TOLLS_AMOUNT  EHAIL_FEE  IMPROVEMENT_SURCHARGE  \
# 0             5.50  ...          0.00       None                    0.3
# 1            10.00  ...          0.00       None                    0.3
# 2             6.00  ...          0.00       None                    0.3
# 3             8.00  ...          0.00       None                    0.3
# 4           -52.00  ...          0.00       None                   -0.3
# ...            ...  ...           ...        ...                    ...
# 76513        56.23  ...          6.12       None                    0.3
# 76514        46.66  ...          6.12       None                    0.3
# 76515        18.95  ...          0.00       None                    0.3
# 76516        48.87  ...          6.12       None                    0.3
# 76517        15.45  ...          0.00       None                    0.3
#
#        TOTAL_AMOUNT PAYMENT_TYPE  TRIP_TYPE  CONGESTION_SURCHARGE    PU_DO  \
# 0              6.80          2.0        1.0                  0.00   43_151
# 1             16.86          1.0        1.0                  2.75  166_239
# 2              8.30          1.0        1.0                  0.00    41_42
# 3              9.30          2.0        1.0                  0.00   168_75
# 4            -52.80          3.0        1.0                  0.00  265_265
# ...             ...          ...        ...                   ...      ...
# 76513         65.40          NaN        NaN                   NaN    81_90
# 76514         65.28          NaN        NaN                   NaN   35_213
# 76515         22.00          NaN        NaN                   NaN    74_69
# 76516         58.04          NaN        NaN                   NaN  168_215
# 76517         18.50          NaN        NaN                   NaN  119_244
#
#           target  prediction
# 0       3.933333    6.120171
# 1       8.750000   10.265737
# 2       5.966667    6.757073
# 3       7.083333   14.444309
# 4       0.066667   15.236120
# ...          ...         ...
# 76513  38.000000   41.961900
# 76514  38.000000   33.436942
# 76515  11.000000   16.366728
# 76516  27.000000   33.323312
# 76517  10.000000   14.781385
#
# [76518 rows x 23 columns]

# %%
client = MongoClient("mongodb://localhost:27017/")
data = client.get_database("prediction_service").get_collection("data").find()
df = pandas.DataFrame(list(data))

# %%
reference_data = reference_data.drop('EHAIL_FEE', axis=1)

# %%
profile = Profile(sections=[DataDriftProfileSection(), RegressionPerformanceProfileSection()])
mapping = ColumnMapping(prediction="prediction", numerical_features=['TRIP_DISTANCE'],
                        categorical_features=['PULOCATIONID', 'DOLOCATIONID'],
                        datetime_features=[])

# %%
df
# Out:
#                            _id  prediction  PULOCATIONID  DOLOCATIONID  \
# 0     62c51f03146bd6672df7d948    1.023000           NaN           NaN
# 1     62c5225f146bd6672df7d94a    1.023000           NaN           NaN
# 2     62c67dd74a12ef4de4860a2d    1.023000           NaN           NaN
# 3     62c67de328a31bc17624a008   21.578591          42.0          42.0
# 4     62c67ebf28a31bc17624a009   21.578591          42.0          42.0
# ...                        ...         ...           ...           ...
# 8813  62c74454b0784dc7fc4b61a2   15.191871         244.0         167.0
# 8814  62c74455b0784dc7fc4b61a3    4.717365         159.0         159.0
# 8815  62c74456b0784dc7fc4b61a4   26.437578          66.0         238.0
# 8816  62c74457b0784dc7fc4b61a5    8.996568          41.0          75.0
# 8817  62c74458b0784dc7fc4b61a6   15.860309          74.0         239.0
#
#       TRIP_DISTANCE  ROUTE    PU_DO
# 0               NaN    NaN      NaN
# 1               NaN    NaN      NaN
# 2               NaN    NaN      NaN
# 3              0.44  42_42      NaN
# 4              0.44  42_42      NaN
# ...             ...    ...      ...
# 8813           3.47    NaN  244_167
# 8814           2.45    NaN  159_159
# 8815           8.98    NaN   66_238
# 8816           0.62    NaN    41_75
# 8817           3.08    NaN   74_239
#
# [8818 rows x 7 columns]

# %%
reference_data
# Out:
#        VENDORID LPEP_PICKUP_DATETIME LPEP_DROPOFF_DATETIME STORE_AND_FWD_FLAG  \
# 0             2  2021-01-01 00:15:56   2021-01-01 00:19:52                  N
# 1             2  2021-01-01 00:25:59   2021-01-01 00:34:44                  N
# 2             2  2021-01-01 00:45:57   2021-01-01 00:51:55                  N
# 3             2  2020-12-31 23:57:51   2021-01-01 00:04:56                  N
# 4             2  2021-01-01 00:16:36   2021-01-01 00:16:40                  N
# ...         ...                  ...                   ...                ...
# 76513         2  2021-01-31 21:38:00   2021-01-31 22:16:00               None
# 76514         2  2021-01-31 22:43:00   2021-01-31 23:21:00               None
# 76515         2  2021-01-31 22:16:00   2021-01-31 22:27:00               None
# 76516         2  2021-01-31 23:10:00   2021-01-31 23:37:00               None
# 76517         2  2021-01-31 23:25:00   2021-01-31 23:35:00               None
#
#        RATECODEID  PULOCATIONID  DOLOCATIONID  PASSENGER_COUNT  TRIP_DISTANCE  \
# 0             1.0            43           151              1.0           1.01
# 1             1.0           166           239              1.0           2.53
# 2             1.0            41            42              1.0           1.12
# 3             1.0           168            75              1.0           1.99
# 4             2.0           265           265              3.0           0.00
# ...           ...           ...           ...              ...            ...
# 76513         NaN            81            90              NaN          17.63
# 76514         NaN            35           213              NaN          18.36
# 76515         NaN            74            69              NaN           2.50
# 76516         NaN           168           215              NaN          14.48
# 76517         NaN           119           244              NaN           1.81
#
#        FARE_AMOUNT  ...  TIP_AMOUNT  TOLLS_AMOUNT  IMPROVEMENT_SURCHARGE  \
# 0             5.50  ...        0.00          0.00                    0.3
# 1            10.00  ...        2.81          0.00                    0.3
# 2             6.00  ...        1.00          0.00                    0.3
# 3             8.00  ...        0.00          0.00                    0.3
# 4           -52.00  ...        0.00          0.00                   -0.3
# ...            ...  ...         ...           ...                    ...
# 76513        56.23  ...        0.00          6.12                    0.3
# 76514        46.66  ...       12.20          6.12                    0.3
# 76515        18.95  ...        0.00          0.00                    0.3
# 76516        48.87  ...        0.00          6.12                    0.3
# 76517        15.45  ...        0.00          0.00                    0.3
#
#        TOTAL_AMOUNT  PAYMENT_TYPE  TRIP_TYPE  CONGESTION_SURCHARGE    PU_DO  \
# 0              6.80           2.0        1.0                  0.00   43_151
# 1             16.86           1.0        1.0                  2.75  166_239
# 2              8.30           1.0        1.0                  0.00    41_42
# 3              9.30           2.0        1.0                  0.00   168_75
# 4            -52.80           3.0        1.0                  0.00  265_265
# ...             ...           ...        ...                   ...      ...
# 76513         65.40           NaN        NaN                   NaN    81_90
# 76514         65.28           NaN        NaN                   NaN   35_213
# 76515         22.00           NaN        NaN                   NaN    74_69
# 76516         58.04           NaN        NaN                   NaN  168_215
# 76517         18.50           NaN        NaN                   NaN  119_244
#
#           target prediction
# 0       3.933333   6.120171
# 1       8.750000  10.265737
# 2       5.966667   6.757073
# 3       7.083333  14.444309
# 4       0.066667  15.236120
# ...          ...        ...
# 76513  38.000000  41.961900
# 76514  38.000000  33.436942
# 76515  11.000000  16.366728
# 76516  27.000000  33.323312
# 76517  10.000000  14.781385
#
# [76518 rows x 22 columns]

# %%
profile.calculate(reference_data, df, mapping)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb Cell 29' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/zar/Desktop/the-prairie/mlops-farmcamp/05_monitoring/test_prediction_service.ipynb#ch0000030?line=0'>1</a> profile.calculate(reference_data, df, mapping)
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/evidently/model_profile/model_profile.py:34, in Profile.calculate(self, reference_data, current_data, column_mapping)
#      28 def calculate(
#      29     self,
#      30     reference_data: pandas.DataFrame,
#      31     current_data: Optional[pandas.DataFrame] = None,
#      32     column_mapping: Optional[ColumnMapping] = None,
#      33 ) -> None:
# ---> 34     self.execute(reference_data, current_data, column_mapping)
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/evidently/pipeline/pipeline.py:46, in Pipeline.execute(self, reference_data, current_data, column_mapping)
#      44     instance = analyzer()
#      45     instance.options_provider = self.options_provider
# ---> 46     self.analyzers_results[analyzer] = instance.calculate(rdata, cdata, column_mapping)
#      47 for stage in self.stages:
#      48     stage.options_provider = self.options_provider
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/evidently/analyzers/data_drift_analyzer.py:105, in DataDriftAnalyzer.calculate(self, reference_data, current_data, column_mapping)
#     103 feature_type = "num"
#     104 ref_feature = reference_data[feature_name].replace([-np.inf, np.inf], np.nan).dropna()
# --> 105 curr_feature = current_data[feature_name].replace([-np.inf, np.inf], np.nan).dropna()
#     106 test = get_stattest(ref_feature,
#     107                     curr_feature,
#     108                     feature_type,
#     109                     data_drift_options.get_feature_stattest_func(feature_name, feature_type))
#     110 drift_result = test(
#     111     ref_feature,
#     112     curr_feature,
#     113     feature_type,
#     114     threshold
#     115 )
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/Envs/05_monitoring-7fNjJXT3-python/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'target'

# %%
dashboard = Dashboard(tabs=[DataDriftTab(), RegressionPerformanceTab(verbose_level=0)])
dashboard.calculate(reference_data, df, mapping)

# %%
list(collection.find())
# Out:
# [{'_id': ObjectId('62c51f03146bd6672df7d948'), 'prediction': 1.023},
#  {'_id': ObjectId('62c5225f146bd6672df7d94a'), 'prediction': 1.023},
#  {'_id': ObjectId('62c67dd74a12ef4de4860a2d'), 'prediction': 1.023},
#  {'_id': ObjectId('62c67de328a31bc17624a008'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 0.44,
#   'ROUTE': '42_42',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ebf28a31bc17624a009'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 0.44,
#   'ROUTE': '42_42',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ec028a31bc17624a00a'),
#   'PULOCATIONID': 116,
#   'DOLOCATIONID': 41,
#   'TRIP_DISTANCE': 2.1,
#   'ROUTE': '116_41',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ec128a31bc17624a00b'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 140,
#   'TRIP_DISTANCE': 3.7,
#   'ROUTE': '41_140',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ec228a31bc17624a00c'),
#   'PULOCATIONID': 181,
#   'DOLOCATIONID': 181,
#   'TRIP_DISTANCE': 1.69,
#   'ROUTE': '181_181',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ec328a31bc17624a00d'),
#   'PULOCATIONID': 33,
#   'DOLOCATIONID': 170,
#   'TRIP_DISTANCE': 6.26,
#   'ROUTE': '33_170',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ec428a31bc17624a00e'),
#   'PULOCATIONID': 150,
#   'DOLOCATIONID': 210,
#   'TRIP_DISTANCE': 1.3,
#   'ROUTE': '150_210',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ec528a31bc17624a00f'),
#   'PULOCATIONID': 66,
#   'DOLOCATIONID': 67,
#   'TRIP_DISTANCE': 6.47,
#   'ROUTE': '66_67',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ec628a31bc17624a010'),
#   'PULOCATIONID': 40,
#   'DOLOCATIONID': 195,
#   'TRIP_DISTANCE': 1.15,
#   'ROUTE': '40_195',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ec728a31bc17624a011'),
#   'PULOCATIONID': 112,
#   'DOLOCATIONID': 80,
#   'TRIP_DISTANCE': 1.3,
#   'ROUTE': '112_80',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ec828a31bc17624a012'),
#   'PULOCATIONID': 256,
#   'DOLOCATIONID': 186,
#   'TRIP_DISTANCE': 4.75,
#   'ROUTE': '256_186',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ec928a31bc17624a013'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 4,
#   'TRIP_DISTANCE': 6.03,
#   'ROUTE': '75_4',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67eca28a31bc17624a014'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 116,
#   'TRIP_DISTANCE': 2.82,
#   'ROUTE': '41_116',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ecb28a31bc17624a015'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 74,
#   'TRIP_DISTANCE': 0.7,
#   'ROUTE': '75_74',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ecd28a31bc17624a016'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 260,
#   'TRIP_DISTANCE': 5.48,
#   'ROUTE': '74_260',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ece28a31bc17624a017'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 231,
#   'TRIP_DISTANCE': 7.54,
#   'ROUTE': '74_231',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ecf28a31bc17624a018'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 0.9,
#   'ROUTE': '74_42',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ed028a31bc17624a019'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 94,
#   'TRIP_DISTANCE': 6.2,
#   'ROUTE': '41_94',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ed128a31bc17624a01a'),
#   'PULOCATIONID': 213,
#   'DOLOCATIONID': 174,
#   'TRIP_DISTANCE': 5.57,
#   'ROUTE': '213_174',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ed228a31bc17624a01b'),
#   'PULOCATIONID': 51,
#   'DOLOCATIONID': 185,
#   'TRIP_DISTANCE': 1.87,
#   'ROUTE': '51_185',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ed328a31bc17624a01c'),
#   'PULOCATIONID': 185,
#   'DOLOCATIONID': 119,
#   'TRIP_DISTANCE': 6.6,
#   'ROUTE': '185_119',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ed428a31bc17624a01d'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 260,
#   'TRIP_DISTANCE': 0.26,
#   'ROUTE': '129_260',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ed528a31bc17624a01e'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 260,
#   'TRIP_DISTANCE': 1.79,
#   'ROUTE': '82_260',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ed628a31bc17624a01f'),
#   'PULOCATIONID': 235,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 2.34,
#   'ROUTE': '235_42',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ed728a31bc17624a020'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 225,
#   'TRIP_DISTANCE': 3.66,
#   'ROUTE': '255_225',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ed828a31bc17624a021'),
#   'PULOCATIONID': 66,
#   'DOLOCATIONID': 234,
#   'TRIP_DISTANCE': 3.96,
#   'ROUTE': '66_234',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ed928a31bc17624a022'),
#   'PULOCATIONID': 33,
#   'DOLOCATIONID': 233,
#   'TRIP_DISTANCE': 6.2,
#   'ROUTE': '33_233',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67eda28a31bc17624a023'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 135,
#   'TRIP_DISTANCE': 2.19,
#   'ROUTE': '95_135',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67edb28a31bc17624a024'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 157,
#   'TRIP_DISTANCE': 4.3,
#   'ROUTE': '95_157',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67edc28a31bc17624a025'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 256,
#   'TRIP_DISTANCE': 0.71,
#   'ROUTE': '255_256',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67edd28a31bc17624a026'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '42_264',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ede28a31bc17624a027'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 74,
#   'TRIP_DISTANCE': 1.55,
#   'ROUTE': '41_74',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67edf28a31bc17624a028'),
#   'PULOCATIONID': 240,
#   'DOLOCATIONID': 259,
#   'TRIP_DISTANCE': 0.88,
#   'ROUTE': '240_259',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ee028a31bc17624a029'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 1.72,
#   'ROUTE': '74_42',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ee128a31bc17624a02a'),
#   'PULOCATIONID': 97,
#   'DOLOCATIONID': 61,
#   'TRIP_DISTANCE': 3.13,
#   'ROUTE': '97_61',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ee228a31bc17624a02b'),
#   'PULOCATIONID': 55,
#   'DOLOCATIONID': 29,
#   'TRIP_DISTANCE': 1.81,
#   'ROUTE': '55_29',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ee328a31bc17624a02c'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 47,
#   'TRIP_DISTANCE': 5.74,
#   'ROUTE': '75_47',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ee428a31bc17624a02d'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 24,
#   'TRIP_DISTANCE': 2.14,
#   'ROUTE': '74_24',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ee528a31bc17624a02e'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 41,
#   'TRIP_DISTANCE': 0.58,
#   'ROUTE': '41_41',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ee628a31bc17624a02f'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 0.81,
#   'ROUTE': '42_42',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ee728a31bc17624a030'),
#   'PULOCATIONID': 168,
#   'DOLOCATIONID': 159,
#   'TRIP_DISTANCE': 1.19,
#   'ROUTE': '168_159',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ee828a31bc17624a031'),
#   'PULOCATIONID': 159,
#   'DOLOCATIONID': 152,
#   'TRIP_DISTANCE': 2.96,
#   'ROUTE': '159_152',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ee928a31bc17624a032'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 0.22,
#   'ROUTE': '129_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67eea28a31bc17624a033'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 74,
#   'TRIP_DISTANCE': 0.94,
#   'ROUTE': '74_74',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67eeb28a31bc17624a034'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 41,
#   'TRIP_DISTANCE': 1.09,
#   'ROUTE': '42_41',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67eec28a31bc17624a035'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 152,
#   'TRIP_DISTANCE': 1.02,
#   'ROUTE': '166_152',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67eed28a31bc17624a036'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 244,
#   'TRIP_DISTANCE': 1.92,
#   'ROUTE': '166_244',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67eee28a31bc17624a037'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 1.32,
#   'ROUTE': '41_42',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67eef28a31bc17624a038'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 238,
#   'TRIP_DISTANCE': 1.77,
#   'ROUTE': '41_238',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ef128a31bc17624a039'),
#   'PULOCATIONID': 130,
#   'DOLOCATIONID': 80,
#   'TRIP_DISTANCE': 9.46,
#   'ROUTE': '130_80',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ef228a31bc17624a03a'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 226,
#   'TRIP_DISTANCE': 1.81,
#   'ROUTE': '7_226',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ef328a31bc17624a03b'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 151,
#   'TRIP_DISTANCE': 1.21,
#   'ROUTE': '75_151',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ef428a31bc17624a03c'),
#   'PULOCATIONID': 66,
#   'DOLOCATIONID': 48,
#   'TRIP_DISTANCE': 5.8,
#   'ROUTE': '66_48',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ef528a31bc17624a03d'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 232,
#   'TRIP_DISTANCE': 2.14,
#   'ROUTE': '255_232',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ef628a31bc17624a03e'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 130,
#   'TRIP_DISTANCE': 2.29,
#   'ROUTE': '95_130',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ef728a31bc17624a03f'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 135,
#   'TRIP_DISTANCE': 1.18,
#   'ROUTE': '95_135',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ef828a31bc17624a040'),
#   'PULOCATIONID': 25,
#   'DOLOCATIONID': 90,
#   'TRIP_DISTANCE': 4.75,
#   'ROUTE': '25_90',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67ef928a31bc17624a041'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 41,
#   'TRIP_DISTANCE': 0.04,
#   'ROUTE': '41_41',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67efa28a31bc17624a042'),
#   'PULOCATIONID': 33,
#   'DOLOCATIONID': 141,
#   'TRIP_DISTANCE': 7.2,
#   'ROUTE': '33_141',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67efb28a31bc17624a043'),
#   'PULOCATIONID': 33,
#   'DOLOCATIONID': 88,
#   'TRIP_DISTANCE': 2.7,
#   'ROUTE': '33_88',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67efc28a31bc17624a044'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 151,
#   'TRIP_DISTANCE': 1.16,
#   'ROUTE': '41_151',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67efd28a31bc17624a045'),
#   'PULOCATIONID': 43,
#   'DOLOCATIONID': 163,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '43_163',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67efe28a31bc17624a046'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 75,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '75_75',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67eff28a31bc17624a047'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 159,
#   'TRIP_DISTANCE': 2.72,
#   'ROUTE': '42_159',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0028a31bc17624a048'),
#   'PULOCATIONID': 159,
#   'DOLOCATIONID': 74,
#   'TRIP_DISTANCE': 1.85,
#   'ROUTE': '159_74',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0128a31bc17624a049'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 143,
#   'TRIP_DISTANCE': 6.4,
#   'ROUTE': '255_143',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0228a31bc17624a04a'),
#   'PULOCATIONID': 116,
#   'DOLOCATIONID': 127,
#   'TRIP_DISTANCE': 3.3,
#   'ROUTE': '116_127',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0328a31bc17624a04b'),
#   'PULOCATIONID': 29,
#   'DOLOCATIONID': 210,
#   'TRIP_DISTANCE': 0.9,
#   'ROUTE': '29_210',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0428a31bc17624a04c'),
#   'PULOCATIONID': 112,
#   'DOLOCATIONID': 80,
#   'TRIP_DISTANCE': 0.9,
#   'ROUTE': '112_80',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0528a31bc17624a04d'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 225,
#   'TRIP_DISTANCE': 10.49,
#   'ROUTE': '75_225',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0628a31bc17624a04e'),
#   'PULOCATIONID': 80,
#   'DOLOCATIONID': 80,
#   'TRIP_DISTANCE': 1.6,
#   'ROUTE': '80_80',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0728a31bc17624a04f'),
#   'PULOCATIONID': 92,
#   'DOLOCATIONID': 265,
#   'TRIP_DISTANCE': 16.38,
#   'ROUTE': '92_265',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0828a31bc17624a050'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 112,
#   'TRIP_DISTANCE': 0.93,
#   'ROUTE': '255_112',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0928a31bc17624a051'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 151,
#   'TRIP_DISTANCE': 1.57,
#   'ROUTE': '75_151',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0a28a31bc17624a052'),
#   'PULOCATIONID': 119,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 2.13,
#   'ROUTE': '119_42',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0b28a31bc17624a053'),
#   'PULOCATIONID': 168,
#   'DOLOCATIONID': 248,
#   'TRIP_DISTANCE': 2.89,
#   'ROUTE': '168_248',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0c28a31bc17624a054'),
#   'PULOCATIONID': 260,
#   'DOLOCATIONID': 260,
#   'TRIP_DISTANCE': 1.9,
#   'ROUTE': '260_260',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0d28a31bc17624a055'),
#   'PULOCATIONID': 226,
#   'DOLOCATIONID': 202,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '226_202',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0e28a31bc17624a056'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 82,
#   'TRIP_DISTANCE': 0.87,
#   'ROUTE': '129_82',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f0f28a31bc17624a057'),
#   'PULOCATIONID': 130,
#   'DOLOCATIONID': 191,
#   'TRIP_DISTANCE': 3.53,
#   'ROUTE': '130_191',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1028a31bc17624a058'),
#   'PULOCATIONID': 130,
#   'DOLOCATIONID': 130,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '130_130',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1128a31bc17624a059'),
#   'PULOCATIONID': 215,
#   'DOLOCATIONID': 215,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '215_215',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1228a31bc17624a05a'),
#   'PULOCATIONID': 228,
#   'DOLOCATIONID': 33,
#   'TRIP_DISTANCE': 2.8,
#   'ROUTE': '228_33',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1328a31bc17624a05b'),
#   'PULOCATIONID': 83,
#   'DOLOCATIONID': 260,
#   'TRIP_DISTANCE': 0.62,
#   'ROUTE': '83_260',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1428a31bc17624a05c'),
#   'PULOCATIONID': 146,
#   'DOLOCATIONID': 179,
#   'TRIP_DISTANCE': 1.72,
#   'ROUTE': '146_179',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1528a31bc17624a05d'),
#   'PULOCATIONID': 36,
#   'DOLOCATIONID': 112,
#   'TRIP_DISTANCE': 3.34,
#   'ROUTE': '36_112',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1728a31bc17624a05e'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 70,
#   'TRIP_DISTANCE': 1.8,
#   'ROUTE': '129_70',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1828a31bc17624a05f'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 0.89,
#   'ROUTE': '82_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1928a31bc17624a060'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 260,
#   'TRIP_DISTANCE': 1.5,
#   'ROUTE': '7_260',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1a28a31bc17624a061'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 82,
#   'TRIP_DISTANCE': 0.49,
#   'ROUTE': '129_82',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1b28a31bc17624a062'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 79,
#   'TRIP_DISTANCE': 2.7,
#   'ROUTE': '255_79',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1c28a31bc17624a063'),
#   'PULOCATIONID': 80,
#   'DOLOCATIONID': 112,
#   'TRIP_DISTANCE': 2.44,
#   'ROUTE': '80_112',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1d28a31bc17624a064'),
#   'PULOCATIONID': 112,
#   'DOLOCATIONID': 7,
#   'TRIP_DISTANCE': 3.8,
#   'ROUTE': '112_7',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1e28a31bc17624a065'),
#   'PULOCATIONID': 83,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 1.65,
#   'ROUTE': '83_264',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f1f28a31bc17624a066'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 37,
#   'TRIP_DISTANCE': 5.73,
#   'ROUTE': '82_37',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2028a31bc17624a067'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 75,
#   'TRIP_DISTANCE': 0.69,
#   'ROUTE': '75_75',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2128a31bc17624a068'),
#   'PULOCATIONID': 260,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 0.77,
#   'ROUTE': '260_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2228a31bc17624a069'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 95,
#   'TRIP_DISTANCE': 0.36,
#   'ROUTE': '95_95',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2328a31bc17624a06a'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 2.99,
#   'ROUTE': '129_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2428a31bc17624a06b'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 260,
#   'TRIP_DISTANCE': 20.49,
#   'ROUTE': '129_260',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2528a31bc17624a06c'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 143,
#   'TRIP_DISTANCE': 3.84,
#   'ROUTE': '42_143',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2628a31bc17624a06d'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 167,
#   'TRIP_DISTANCE': 4.2,
#   'ROUTE': '41_167',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2728a31bc17624a06e'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 179,
#   'TRIP_DISTANCE': 1.09,
#   'ROUTE': '7_179',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2828a31bc17624a06f'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 223,
#   'TRIP_DISTANCE': 2.21,
#   'ROUTE': '7_223',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2928a31bc17624a070'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 7,
#   'TRIP_DISTANCE': 0.19,
#   'ROUTE': '7_7',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2a28a31bc17624a071'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 1.04,
#   'ROUTE': '129_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2b28a31bc17624a072'),
#   'PULOCATIONID': 168,
#   'DOLOCATIONID': 213,
#   'TRIP_DISTANCE': 9.18,
#   'ROUTE': '168_213',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2c28a31bc17624a073'),
#   'PULOCATIONID': 260,
#   'DOLOCATIONID': 226,
#   'TRIP_DISTANCE': 0.95,
#   'ROUTE': '260_226',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2d28a31bc17624a074'),
#   'PULOCATIONID': 179,
#   'DOLOCATIONID': 193,
#   'TRIP_DISTANCE': 1.48,
#   'ROUTE': '179_193',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2e28a31bc17624a075'),
#   'PULOCATIONID': 112,
#   'DOLOCATIONID': 232,
#   'TRIP_DISTANCE': 3.61,
#   'ROUTE': '112_232',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f2f28a31bc17624a076'),
#   'PULOCATIONID': 55,
#   'DOLOCATIONID': 229,
#   'TRIP_DISTANCE': 18.05,
#   'ROUTE': '55_229',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3028a31bc17624a077'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 166,
#   'TRIP_DISTANCE': 0.72,
#   'ROUTE': '42_166',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3128a31bc17624a078'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 166,
#   'TRIP_DISTANCE': 0.72,
#   'ROUTE': '42_166',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3228a31bc17624a079'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 146,
#   'TRIP_DISTANCE': 5.33,
#   'ROUTE': '41_146',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3328a31bc17624a07a'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 260,
#   'TRIP_DISTANCE': 1.2,
#   'ROUTE': '129_260',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3428a31bc17624a07b'),
#   'PULOCATIONID': 260,
#   'DOLOCATIONID': 82,
#   'TRIP_DISTANCE': 1.41,
#   'ROUTE': '260_82',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3528a31bc17624a07c'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 50,
#   'TRIP_DISTANCE': 5.97,
#   'ROUTE': '41_50',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3628a31bc17624a07d'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 95,
#   'TRIP_DISTANCE': 0.87,
#   'ROUTE': '95_95',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3728a31bc17624a07e'),
#   'PULOCATIONID': 92,
#   'DOLOCATIONID': 92,
#   'TRIP_DISTANCE': 5.72,
#   'ROUTE': '92_92',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3828a31bc17624a07f'),
#   'PULOCATIONID': 92,
#   'DOLOCATIONID': 171,
#   'TRIP_DISTANCE': 1.58,
#   'ROUTE': '92_171',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3928a31bc17624a080'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 95,
#   'TRIP_DISTANCE': 0.53,
#   'ROUTE': '95_95',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3b28a31bc17624a081'),
#   'PULOCATIONID': 66,
#   'DOLOCATIONID': 158,
#   'TRIP_DISTANCE': 3.8,
#   'ROUTE': '66_158',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3c28a31bc17624a082'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 247,
#   'TRIP_DISTANCE': 3.0,
#   'ROUTE': '42_247',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3d28a31bc17624a083'),
#   'PULOCATIONID': 119,
#   'DOLOCATIONID': 244,
#   'TRIP_DISTANCE': 2.13,
#   'ROUTE': '119_244',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3e28a31bc17624a084'),
#   'PULOCATIONID': 61,
#   'DOLOCATIONID': 246,
#   'TRIP_DISTANCE': 8.69,
#   'ROUTE': '61_246',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f3f28a31bc17624a085'),
#   'PULOCATIONID': 33,
#   'DOLOCATIONID': 52,
#   'TRIP_DISTANCE': 0.42,
#   'ROUTE': '33_52',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4028a31bc17624a086'),
#   'PULOCATIONID': 108,
#   'DOLOCATIONID': 210,
#   'TRIP_DISTANCE': 0.9,
#   'ROUTE': '108_210',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4128a31bc17624a087'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 256,
#   'TRIP_DISTANCE': 0.6,
#   'ROUTE': '255_256',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4228a31bc17624a088'),
#   'PULOCATIONID': 130,
#   'DOLOCATIONID': 265,
#   'TRIP_DISTANCE': 9.25,
#   'ROUTE': '130_265',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4328a31bc17624a089'),
#   'PULOCATIONID': 250,
#   'DOLOCATIONID': 143,
#   'TRIP_DISTANCE': 10.81,
#   'ROUTE': '250_143',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4428a31bc17624a08a'),
#   'PULOCATIONID': 146,
#   'DOLOCATIONID': 179,
#   'TRIP_DISTANCE': 1.7,
#   'ROUTE': '146_179',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4528a31bc17624a08b'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 137,
#   'TRIP_DISTANCE': 5.7,
#   'ROUTE': '41_137',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4628a31bc17624a08c'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 238,
#   'TRIP_DISTANCE': 1.07,
#   'ROUTE': '75_238',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4728a31bc17624a08d'),
#   'PULOCATIONID': 69,
#   'DOLOCATIONID': 212,
#   'TRIP_DISTANCE': 3.79,
#   'ROUTE': '69_212',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4828a31bc17624a08e'),
#   'PULOCATIONID': 130,
#   'DOLOCATIONID': 205,
#   'TRIP_DISTANCE': 4.18,
#   'ROUTE': '130_205',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4928a31bc17624a08f'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 2.17,
#   'ROUTE': '82_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4a28a31bc17624a090'),
#   'PULOCATIONID': 85,
#   'DOLOCATIONID': 35,
#   'TRIP_DISTANCE': 4.0,
#   'ROUTE': '85_35',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4b28a31bc17624a091'),
#   'PULOCATIONID': 71,
#   'DOLOCATIONID': 188,
#   'TRIP_DISTANCE': 1.2,
#   'ROUTE': '71_188',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4c28a31bc17624a092'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 74,
#   'TRIP_DISTANCE': 6.92,
#   'ROUTE': '7_74',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4d28a31bc17624a093'),
#   'PULOCATIONID': 173,
#   'DOLOCATIONID': 56,
#   'TRIP_DISTANCE': 1.17,
#   'ROUTE': '173_56',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4e28a31bc17624a094'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 0.6,
#   'ROUTE': '129_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f4f28a31bc17624a095'),
#   'PULOCATIONID': 212,
#   'DOLOCATIONID': 182,
#   'TRIP_DISTANCE': 0.58,
#   'ROUTE': '212_182',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5028a31bc17624a096'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 68,
#   'TRIP_DISTANCE': 7.41,
#   'ROUTE': '74_68',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5128a31bc17624a097'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 126,
#   'TRIP_DISTANCE': 6.6,
#   'ROUTE': '129_126',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5228a31bc17624a098'),
#   'PULOCATIONID': 179,
#   'DOLOCATIONID': 179,
#   'TRIP_DISTANCE': 0.08,
#   'ROUTE': '179_179',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5328a31bc17624a099'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 28,
#   'TRIP_DISTANCE': 2.46,
#   'ROUTE': '95_28',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5428a31bc17624a09a'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 95,
#   'TRIP_DISTANCE': 0.93,
#   'ROUTE': '95_95',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5528a31bc17624a09b'),
#   'PULOCATIONID': 91,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '91_264',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5628a31bc17624a09c'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 1.5,
#   'ROUTE': '82_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5728a31bc17624a09d'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 114,
#   'TRIP_DISTANCE': 3.6,
#   'ROUTE': '255_114',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5828a31bc17624a09e'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 28,
#   'TRIP_DISTANCE': 1.54,
#   'ROUTE': '95_28',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5928a31bc17624a09f'),
#   'PULOCATIONID': 260,
#   'DOLOCATIONID': 82,
#   'TRIP_DISTANCE': 1.07,
#   'ROUTE': '260_82',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5a28a31bc17624a0a0'),
#   'PULOCATIONID': 260,
#   'DOLOCATIONID': 160,
#   'TRIP_DISTANCE': 1.43,
#   'ROUTE': '260_160',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5b28a31bc17624a0a1'),
#   'PULOCATIONID': 182,
#   'DOLOCATIONID': 254,
#   'TRIP_DISTANCE': 4.97,
#   'ROUTE': '182_254',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5c28a31bc17624a0a2'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 141,
#   'TRIP_DISTANCE': 3.9,
#   'ROUTE': '7_141',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5d28a31bc17624a0a3'),
#   'PULOCATIONID': 61,
#   'DOLOCATIONID': 61,
#   'TRIP_DISTANCE': 0.95,
#   'ROUTE': '61_61',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f5f28a31bc17624a0a4'),
#   'PULOCATIONID': 61,
#   'DOLOCATIONID': 61,
#   'TRIP_DISTANCE': 0.95,
#   'ROUTE': '61_61',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6028a31bc17624a0a5'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 244,
#   'TRIP_DISTANCE': 2.17,
#   'ROUTE': '41_244',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6128a31bc17624a0a6'),
#   'PULOCATIONID': 116,
#   'DOLOCATIONID': 116,
#   'TRIP_DISTANCE': 0.57,
#   'ROUTE': '116_116',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6228a31bc17624a0a7'),
#   'PULOCATIONID': 116,
#   'DOLOCATIONID': 116,
#   'TRIP_DISTANCE': 0.57,
#   'ROUTE': '116_116',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6328a31bc17624a0a8'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 3.4,
#   'ROUTE': '166_264',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6428a31bc17624a0a9'),
#   'PULOCATIONID': 264,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '264_264',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6528a31bc17624a0aa'),
#   'PULOCATIONID': 33,
#   'DOLOCATIONID': 256,
#   'TRIP_DISTANCE': 3.3,
#   'ROUTE': '33_256',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6628a31bc17624a0ab'),
#   'PULOCATIONID': 236,
#   'DOLOCATIONID': 229,
#   'TRIP_DISTANCE': 3.17,
#   'ROUTE': '236_229',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6728a31bc17624a0ac'),
#   'PULOCATIONID': 80,
#   'DOLOCATIONID': 80,
#   'TRIP_DISTANCE': 6.69,
#   'ROUTE': '80_80',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6828a31bc17624a0ad'),
#   'PULOCATIONID': 66,
#   'DOLOCATIONID': 143,
#   'TRIP_DISTANCE': 7.0,
#   'ROUTE': '66_143',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6928a31bc17624a0ae'),
#   'PULOCATIONID': 116,
#   'DOLOCATIONID': 166,
#   'TRIP_DISTANCE': 2.05,
#   'ROUTE': '116_166',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6a28a31bc17624a0af'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 41,
#   'TRIP_DISTANCE': 0.61,
#   'ROUTE': '166_41',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6b28a31bc17624a0b0'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 244,
#   'TRIP_DISTANCE': 3.23,
#   'ROUTE': '41_244',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6c28a31bc17624a0b1'),
#   'PULOCATIONID': 244,
#   'DOLOCATIONID': 41,
#   'TRIP_DISTANCE': 3.33,
#   'ROUTE': '244_41',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6d28a31bc17624a0b2'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 6.6,
#   'ROUTE': '255_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6e28a31bc17624a0b3'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 7,
#   'TRIP_DISTANCE': 2.4,
#   'ROUTE': '129_7',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f6f28a31bc17624a0b4'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 258,
#   'TRIP_DISTANCE': 13.1,
#   'ROUTE': '7_258',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7028a31bc17624a0b5'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 238,
#   'TRIP_DISTANCE': 2.6,
#   'ROUTE': '42_238',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7128a31bc17624a0b6'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 18,
#   'TRIP_DISTANCE': 5.45,
#   'ROUTE': '42_18',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7228a31bc17624a0b7'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 4,
#   'TRIP_DISTANCE': 6.13,
#   'ROUTE': '74_4',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7328a31bc17624a0b8'),
#   'PULOCATIONID': 210,
#   'DOLOCATIONID': 210,
#   'TRIP_DISTANCE': 0.6,
#   'ROUTE': '210_210',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7428a31bc17624a0b9'),
#   'PULOCATIONID': 210,
#   'DOLOCATIONID': 210,
#   'TRIP_DISTANCE': 2.3,
#   'ROUTE': '210_210',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7528a31bc17624a0ba'),
#   'PULOCATIONID': 244,
#   'DOLOCATIONID': 235,
#   'TRIP_DISTANCE': 4.61,
#   'ROUTE': '244_235',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7628a31bc17624a0bb'),
#   'PULOCATIONID': 112,
#   'DOLOCATIONID': 80,
#   'TRIP_DISTANCE': 1.14,
#   'ROUTE': '112_80',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7728a31bc17624a0bc'),
#   'PULOCATIONID': 256,
#   'DOLOCATIONID': 41,
#   'TRIP_DISTANCE': 10.52,
#   'ROUTE': '256_41',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7828a31bc17624a0bd'),
#   'PULOCATIONID': 130,
#   'DOLOCATIONID': 10,
#   'TRIP_DISTANCE': 1.31,
#   'ROUTE': '130_10',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7928a31bc17624a0be'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 238,
#   'TRIP_DISTANCE': 2.49,
#   'ROUTE': '74_238',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7a28a31bc17624a0bf'),
#   'PULOCATIONID': 260,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 1.48,
#   'ROUTE': '260_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7b28a31bc17624a0c0'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 239,
#   'TRIP_DISTANCE': 2.22,
#   'ROUTE': '166_239',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7c28a31bc17624a0c1'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 74,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '74_74',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7d28a31bc17624a0c2'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 260,
#   'TRIP_DISTANCE': 0.52,
#   'ROUTE': '129_260',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7e28a31bc17624a0c3'),
#   'PULOCATIONID': 89,
#   'DOLOCATIONID': 14,
#   'TRIP_DISTANCE': 8.8,
#   'ROUTE': '89_14',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f7f28a31bc17624a0c4'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 226,
#   'TRIP_DISTANCE': 1.87,
#   'ROUTE': '7_226',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8028a31bc17624a0c5'),
#   'PULOCATIONID': 28,
#   'DOLOCATIONID': 28,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '28_28',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8128a31bc17624a0c6'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 56,
#   'TRIP_DISTANCE': 5.64,
#   'ROUTE': '7_56',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8228a31bc17624a0c7'),
#   'PULOCATIONID': 17,
#   'DOLOCATIONID': 17,
#   'TRIP_DISTANCE': 0.71,
#   'ROUTE': '17_17',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8428a31bc17624a0c8'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 83,
#   'TRIP_DISTANCE': 0.87,
#   'ROUTE': '129_83',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8528a31bc17624a0c9'),
#   'PULOCATIONID': 205,
#   'DOLOCATIONID': 218,
#   'TRIP_DISTANCE': 1.21,
#   'ROUTE': '205_218',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8628a31bc17624a0ca'),
#   'PULOCATIONID': 112,
#   'DOLOCATIONID': 256,
#   'TRIP_DISTANCE': 1.41,
#   'ROUTE': '112_256',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8728a31bc17624a0cb'),
#   'PULOCATIONID': 80,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '80_264',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8828a31bc17624a0cc'),
#   'PULOCATIONID': 256,
#   'DOLOCATIONID': 79,
#   'TRIP_DISTANCE': 2.35,
#   'ROUTE': '256_79',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8928a31bc17624a0cd'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 2.43,
#   'ROUTE': '82_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8a28a31bc17624a0ce'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 83,
#   'TRIP_DISTANCE': 31.28,
#   'ROUTE': '129_83',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8b28a31bc17624a0cf'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 173,
#   'TRIP_DISTANCE': 1.31,
#   'ROUTE': '82_173',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8c28a31bc17624a0d0'),
#   'PULOCATIONID': 181,
#   'DOLOCATIONID': 228,
#   'TRIP_DISTANCE': 3.32,
#   'ROUTE': '181_228',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8d28a31bc17624a0d1'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 166,
#   'TRIP_DISTANCE': 0.17,
#   'ROUTE': '166_166',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8e28a31bc17624a0d2'),
#   'PULOCATIONID': 197,
#   'DOLOCATIONID': 216,
#   'TRIP_DISTANCE': 0.36,
#   'ROUTE': '197_216',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f8f28a31bc17624a0d3'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 0.9,
#   'ROUTE': '129_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9028a31bc17624a0d4'),
#   'PULOCATIONID': 225,
#   'DOLOCATIONID': 198,
#   'TRIP_DISTANCE': 1.97,
#   'ROUTE': '225_198',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9128a31bc17624a0d5'),
#   'PULOCATIONID': 198,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 11.56,
#   'ROUTE': '198_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9228a31bc17624a0d6'),
#   'PULOCATIONID': 66,
#   'DOLOCATIONID': 65,
#   'TRIP_DISTANCE': 1.1,
#   'ROUTE': '66_65',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9328a31bc17624a0d7'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 138,
#   'TRIP_DISTANCE': 8.22,
#   'ROUTE': '166_138',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9428a31bc17624a0d8'),
#   'PULOCATIONID': 159,
#   'DOLOCATIONID': 213,
#   'TRIP_DISTANCE': 5.09,
#   'ROUTE': '159_213',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9528a31bc17624a0d9'),
#   'PULOCATIONID': 145,
#   'DOLOCATIONID': 179,
#   'TRIP_DISTANCE': 1.65,
#   'ROUTE': '145_179',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9628a31bc17624a0da'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 93,
#   'TRIP_DISTANCE': 2.15,
#   'ROUTE': '129_93',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9728a31bc17624a0db'),
#   'PULOCATIONID': 169,
#   'DOLOCATIONID': 169,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '169_169',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9828a31bc17624a0dc'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 166,
#   'TRIP_DISTANCE': 0.62,
#   'ROUTE': '41_166',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9928a31bc17624a0dd'),
#   'PULOCATIONID': 22,
#   'DOLOCATIONID': 22,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '22_22',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9a28a31bc17624a0de'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 7,
#   'TRIP_DISTANCE': 0.67,
#   'ROUTE': '7_7',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9b28a31bc17624a0df'),
#   'PULOCATIONID': 179,
#   'DOLOCATIONID': 179,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '179_179',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9c28a31bc17624a0e0'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 141,
#   'TRIP_DISTANCE': 4.88,
#   'ROUTE': '255_141',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9d28a31bc17624a0e1'),
#   'PULOCATIONID': 36,
#   'DOLOCATIONID': 255,
#   'TRIP_DISTANCE': 2.81,
#   'ROUTE': '36_255',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9e28a31bc17624a0e2'),
#   'PULOCATIONID': 36,
#   'DOLOCATIONID': 209,
#   'TRIP_DISTANCE': 5.85,
#   'ROUTE': '36_209',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67f9f28a31bc17624a0e3'),
#   'PULOCATIONID': 80,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '80_264',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fa028a31bc17624a0e4'),
#   'PULOCATIONID': 256,
#   'DOLOCATIONID': 167,
#   'TRIP_DISTANCE': 11.44,
#   'ROUTE': '256_167',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fa128a31bc17624a0e5'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 223,
#   'TRIP_DISTANCE': 2.08,
#   'ROUTE': '7_223',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fa228a31bc17624a0e6'),
#   'PULOCATIONID': 223,
#   'DOLOCATIONID': 179,
#   'TRIP_DISTANCE': 0.65,
#   'ROUTE': '223_179',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fa328a31bc17624a0e7'),
#   'PULOCATIONID': 179,
#   'DOLOCATIONID': 146,
#   'TRIP_DISTANCE': 1.67,
#   'ROUTE': '179_146',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fa528a31bc17624a0e8'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 0.26,
#   'ROUTE': '95_264',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fa628a31bc17624a0e9'),
#   'PULOCATIONID': 56,
#   'DOLOCATIONID': 56,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '56_56',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fa728a31bc17624a0ea'),
#   'PULOCATIONID': 56,
#   'DOLOCATIONID': 56,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '56_56',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fa828a31bc17624a0eb'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 1.0,
#   'ROUTE': '41_42',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fa928a31bc17624a0ec'),
#   'PULOCATIONID': 33,
#   'DOLOCATIONID': 181,
#   'TRIP_DISTANCE': 1.98,
#   'ROUTE': '33_181',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67faa28a31bc17624a0ed'),
#   'PULOCATIONID': 18,
#   'DOLOCATIONID': 18,
#   'TRIP_DISTANCE': 0.21,
#   'ROUTE': '18_18',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fab28a31bc17624a0ee'),
#   'PULOCATIONID': 116,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '116_42',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fac28a31bc17624a0ef'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 130,
#   'TRIP_DISTANCE': 2.6,
#   'ROUTE': '95_130',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fad28a31bc17624a0f0'),
#   'PULOCATIONID': 182,
#   'DOLOCATIONID': 159,
#   'TRIP_DISTANCE': 3.19,
#   'ROUTE': '182_159',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fae28a31bc17624a0f1'),
#   'PULOCATIONID': 25,
#   'DOLOCATIONID': 25,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '25_25',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67faf28a31bc17624a0f2'),
#   'PULOCATIONID': 80,
#   'DOLOCATIONID': 255,
#   'TRIP_DISTANCE': 1.88,
#   'ROUTE': '80_255',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fb028a31bc17624a0f3'),
#   'PULOCATIONID': 130,
#   'DOLOCATIONID': 139,
#   'TRIP_DISTANCE': 5.85,
#   'ROUTE': '130_139',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fb128a31bc17624a0f4'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 89,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '82_89',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fb228a31bc17624a0f5'),
#   'PULOCATIONID': 173,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 1.17,
#   'ROUTE': '173_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fb328a31bc17624a0f6'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 265,
#   'TRIP_DISTANCE': 27.97,
#   'ROUTE': '75_265',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fb428a31bc17624a0f7'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 127,
#   'TRIP_DISTANCE': 4.15,
#   'ROUTE': '41_127',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fb528a31bc17624a0f8'),
#   'PULOCATIONID': 116,
#   'DOLOCATIONID': 116,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '116_116',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fb628a31bc17624a0f9'),
#   'PULOCATIONID': 247,
#   'DOLOCATIONID': 247,
#   'TRIP_DISTANCE': 0.94,
#   'ROUTE': '247_247',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fb728a31bc17624a0fa'),
#   'PULOCATIONID': 130,
#   'DOLOCATIONID': 218,
#   'TRIP_DISTANCE': 3.25,
#   'ROUTE': '130_218',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fb828a31bc17624a0fb'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 75,
#   'TRIP_DISTANCE': 0.64,
#   'ROUTE': '41_75',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fb928a31bc17624a0fc'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 80,
#   'TRIP_DISTANCE': 1.61,
#   'ROUTE': '255_80',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fba28a31bc17624a0fd'),
#   'PULOCATIONID': 263,
#   'DOLOCATIONID': 140,
#   'TRIP_DISTANCE': 1.58,
#   'ROUTE': '263_140',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fbb28a31bc17624a0fe'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 75,
#   'TRIP_DISTANCE': 1.43,
#   'ROUTE': '74_75',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fbc28a31bc17624a0ff'),
#   'PULOCATIONID': 250,
#   'DOLOCATIONID': 250,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '250_250',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fbd28a31bc17624a100'),
#   'PULOCATIONID': 213,
#   'DOLOCATIONID': 250,
#   'TRIP_DISTANCE': 1.07,
#   'ROUTE': '213_250',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fbe28a31bc17624a101'),
#   'PULOCATIONID': 71,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '71_264',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fbf28a31bc17624a102'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 119,
#   'TRIP_DISTANCE': 3.73,
#   'ROUTE': '74_119',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fc028a31bc17624a103'),
#   'PULOCATIONID': 226,
#   'DOLOCATIONID': 197,
#   'TRIP_DISTANCE': 7.73,
#   'ROUTE': '226_197',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fc128a31bc17624a104'),
#   'PULOCATIONID': 197,
#   'DOLOCATIONID': 197,
#   'TRIP_DISTANCE': 4.24,
#   'ROUTE': '197_197',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fc228a31bc17624a105'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 239,
#   'TRIP_DISTANCE': 0.48,
#   'ROUTE': '75_239',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fc328a31bc17624a106'),
#   'PULOCATIONID': 226,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 2.67,
#   'ROUTE': '226_129',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fc528a31bc17624a107'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 70,
#   'TRIP_DISTANCE': 1.58,
#   'ROUTE': '82_70',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fc628a31bc17624a108'),
#   'PULOCATIONID': 70,
#   'DOLOCATIONID': 179,
#   'TRIP_DISTANCE': 3.05,
#   'ROUTE': '70_179',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fc728a31bc17624a109'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 193,
#   'TRIP_DISTANCE': 2.36,
#   'ROUTE': '7_193',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fc828a31bc17624a10a'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 254,
#   'TRIP_DISTANCE': 9.32,
#   'ROUTE': '166_254',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fc928a31bc17624a10b'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 37,
#   'TRIP_DISTANCE': 6.35,
#   'ROUTE': '95_37',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fca28a31bc17624a10c'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 151,
#   'TRIP_DISTANCE': 2.29,
#   'ROUTE': '42_151',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fcb28a31bc17624a10d'),
#   'PULOCATIONID': 24,
#   'DOLOCATIONID': 263,
#   'TRIP_DISTANCE': 1.98,
#   'ROUTE': '24_263',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fcc28a31bc17624a10e'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 2.3,
#   'ROUTE': '74_42',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fcd28a31bc17624a10f'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 194,
#   'TRIP_DISTANCE': 3.23,
#   'ROUTE': '41_194',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fce28a31bc17624a110'),
#   'PULOCATIONID': 92,
#   'DOLOCATIONID': 92,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '92_92',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fcf28a31bc17624a111'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 151,
#   'TRIP_DISTANCE': 2.2,
#   'ROUTE': '74_151',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fd028a31bc17624a112'),
#   'PULOCATIONID': 130,
#   'DOLOCATIONID': 130,
#   'TRIP_DISTANCE': 0.0,
#   'ROUTE': '130_130',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fd128a31bc17624a113'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 74,
#   'TRIP_DISTANCE': 0.43,
#   'ROUTE': '41_74',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fd228a31bc17624a114'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 142,
#   'TRIP_DISTANCE': 3.1,
#   'ROUTE': '166_142',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fd328a31bc17624a115'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 186,
#   'TRIP_DISTANCE': 4.0,
#   'ROUTE': '75_186',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fd428a31bc17624a116'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 218,
#   'TRIP_DISTANCE': 10.57,
#   'ROUTE': '82_218',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fd528a31bc17624a117'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 223,
#   'TRIP_DISTANCE': 0.89,
#   'ROUTE': '7_223',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fd628a31bc17624a118'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 75,
#   'TRIP_DISTANCE': 1.79,
#   'ROUTE': '74_75',
#   'prediction': 21.578590757985687},
#  {'_id': ObjectId('62c67fd728a31bc17624a119'),
#   'PULOCATIONID': 74,
# ...
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 244,
#   'TRIP_DISTANCE': 2.17,
#   'PU_DO': '41_244',
#   'prediction': 15.26746187181388},
#  {'_id': ObjectId('62c68a658c6ba847ae6f7f3c'),
#   'PULOCATIONID': 116,
#   'DOLOCATIONID': 116,
#   'TRIP_DISTANCE': 0.57,
#   'PU_DO': '116_116',
#   'prediction': 5.549063637179447},
#  {'_id': ObjectId('62c68a668c6ba847ae6f7f3d'),
#   'PULOCATIONID': 116,
#   'DOLOCATIONID': 116,
#   'TRIP_DISTANCE': 0.57,
#   'PU_DO': '116_116',
#   'prediction': 5.549063637179447},
#  {'_id': ObjectId('62c68a678c6ba847ae6f7f3e'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 3.4,
#   'PU_DO': '166_264',
#   'prediction': 7.429879964544991},
#  {'_id': ObjectId('62c68a688c6ba847ae6f7f3f'),
#   'PULOCATIONID': 264,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '264_264',
#   'prediction': 10.797562386035143},
#  {'_id': ObjectId('62c68a698c6ba847ae6f7f40'),
#   'PULOCATIONID': 33,
#   'DOLOCATIONID': 256,
#   'TRIP_DISTANCE': 3.3,
#   'PU_DO': '33_256',
#   'prediction': 18.90919911061038},
#  {'_id': ObjectId('62c68a6a8c6ba847ae6f7f41'),
#   'PULOCATIONID': 236,
#   'DOLOCATIONID': 229,
#   'TRIP_DISTANCE': 3.17,
#   'PU_DO': '236_229',
#   'prediction': 16.12941492146286},
#  {'_id': ObjectId('62c68a6b8c6ba847ae6f7f42'),
#   'PULOCATIONID': 80,
#   'DOLOCATIONID': 80,
#   'TRIP_DISTANCE': 6.69,
#   'PU_DO': '80_80',
#   'prediction': 10.437700404898186},
#  {'_id': ObjectId('62c68a6c8c6ba847ae6f7f43'),
#   'PULOCATIONID': 66,
#   'DOLOCATIONID': 143,
#   'TRIP_DISTANCE': 7.0,
#   'PU_DO': '66_143',
#   'prediction': 26.4375784155702},
#  {'_id': ObjectId('62c68a6d8c6ba847ae6f7f44'),
#   'PULOCATIONID': 116,
#   'DOLOCATIONID': 166,
#   'TRIP_DISTANCE': 2.05,
#   'PU_DO': '116_166',
#   'prediction': 8.044726843588624},
#  {'_id': ObjectId('62c68a6e8c6ba847ae6f7f45'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 41,
#   'TRIP_DISTANCE': 0.61,
#   'PU_DO': '166_41',
#   'prediction': 7.130406145659258},
#  {'_id': ObjectId('62c68a6f8c6ba847ae6f7f46'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 244,
#   'TRIP_DISTANCE': 3.23,
#   'PU_DO': '41_244',
#   'prediction': 15.26746187181388},
#  {'_id': ObjectId('62c68a708c6ba847ae6f7f47'),
#   'PULOCATIONID': 244,
#   'DOLOCATIONID': 41,
#   'TRIP_DISTANCE': 3.33,
#   'PU_DO': '244_41',
#   'prediction': 16.234748070598002},
#  {'_id': ObjectId('62c68a718c6ba847ae6f7f48'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 6.6,
#   'PU_DO': '255_129',
#   'prediction': 19.067640628104943},
#  {'_id': ObjectId('62c68a728c6ba847ae6f7f49'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 7,
#   'TRIP_DISTANCE': 2.4,
#   'PU_DO': '129_7',
#   'prediction': 11.869712684492383},
#  {'_id': ObjectId('62c68a738c6ba847ae6f7f4a'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 258,
#   'TRIP_DISTANCE': 13.1,
#   'PU_DO': '7_258',
#   'prediction': 31.520869429321202},
#  {'_id': ObjectId('62c68a748c6ba847ae6f7f4b'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 238,
#   'TRIP_DISTANCE': 2.6,
#   'PU_DO': '42_238',
#   'prediction': 15.858219781992446},
#  {'_id': ObjectId('62c68a758c6ba847ae6f7f4c'),
#   'PULOCATIONID': 42,
#   'DOLOCATIONID': 18,
#   'TRIP_DISTANCE': 5.45,
#   'PU_DO': '42_18',
#   'prediction': 20.988985619686456},
#  {'_id': ObjectId('62c68a768c6ba847ae6f7f4d'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 4,
#   'TRIP_DISTANCE': 6.13,
#   'PU_DO': '74_4',
#   'prediction': 19.28011468565854},
#  {'_id': ObjectId('62c68a778c6ba847ae6f7f4e'),
#   'PULOCATIONID': 210,
#   'DOLOCATIONID': 210,
#   'TRIP_DISTANCE': 0.6,
#   'PU_DO': '210_210',
#   'prediction': 5.657510004830655},
#  {'_id': ObjectId('62c68a788c6ba847ae6f7f4f'),
#   'PULOCATIONID': 210,
#   'DOLOCATIONID': 210,
#   'TRIP_DISTANCE': 2.3,
#   'PU_DO': '210_210',
#   'prediction': 5.657510004830655},
#  {'_id': ObjectId('62c68a798c6ba847ae6f7f50'),
#   'PULOCATIONID': 244,
#   'DOLOCATIONID': 235,
#   'TRIP_DISTANCE': 4.61,
#   'PU_DO': '244_235',
#   'prediction': 12.796014447048423},
#  {'_id': ObjectId('62c68a7a8c6ba847ae6f7f51'),
#   'PULOCATIONID': 112,
#   'DOLOCATIONID': 80,
#   'TRIP_DISTANCE': 1.14,
#   'PU_DO': '112_80',
#   'prediction': 8.231932954968727},
#  {'_id': ObjectId('62c68a7b8c6ba847ae6f7f52'),
#   'PULOCATIONID': 256,
#   'DOLOCATIONID': 41,
#   'TRIP_DISTANCE': 10.52,
#   'PU_DO': '256_41',
#   'prediction': 26.4375784155702},
#  {'_id': ObjectId('62c68a7c8c6ba847ae6f7f53'),
#   'PULOCATIONID': 130,
#   'DOLOCATIONID': 10,
#   'TRIP_DISTANCE': 1.31,
#   'PU_DO': '130_10',
#   'prediction': 10.581872479689782},
#  {'_id': ObjectId('62c68a7d8c6ba847ae6f7f54'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 238,
#   'TRIP_DISTANCE': 2.49,
#   'PU_DO': '74_238',
#   'prediction': 14.991258109317256},
#  {'_id': ObjectId('62c68a7e8c6ba847ae6f7f55'),
#   'PULOCATIONID': 260,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 1.48,
#   'PU_DO': '260_129',
#   'prediction': 10.567256593641332},
#  {'_id': ObjectId('62c68a7f8c6ba847ae6f7f56'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 239,
#   'TRIP_DISTANCE': 2.22,
#   'PU_DO': '166_239',
#   'prediction': 10.265737151571265},
#  {'_id': ObjectId('62c68a808c6ba847ae6f7f57'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 74,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '74_74',
#   'prediction': 5.76168240460531},
#  {'_id': ObjectId('62c68a828c6ba847ae6f7f58'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 260,
#   'TRIP_DISTANCE': 0.52,
#   'PU_DO': '129_260',
#   'prediction': 9.005017931937687},
#  {'_id': ObjectId('62c68a838c6ba847ae6f7f59'),
#   'PULOCATIONID': 89,
#   'DOLOCATIONID': 14,
#   'TRIP_DISTANCE': 8.8,
#   'PU_DO': '89_14',
#   'prediction': 24.01640818588299},
#  {'_id': ObjectId('62c68a848c6ba847ae6f7f5a'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 226,
#   'TRIP_DISTANCE': 1.87,
#   'PU_DO': '7_226',
#   'prediction': 10.645784080558986},
#  {'_id': ObjectId('62c68a858c6ba847ae6f7f5b'),
#   'PULOCATIONID': 28,
#   'DOLOCATIONID': 28,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '28_28',
#   'prediction': 1.056664096400123},
#  {'_id': ObjectId('62c68a868c6ba847ae6f7f5c'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 56,
#   'TRIP_DISTANCE': 5.64,
#   'PU_DO': '7_56',
#   'prediction': 19.87341228848741},
#  {'_id': ObjectId('62c68a878c6ba847ae6f7f5d'),
#   'PULOCATIONID': 17,
#   'DOLOCATIONID': 17,
#   'TRIP_DISTANCE': 0.71,
#   'PU_DO': '17_17',
#   'prediction': 5.6798543325923205},
#  {'_id': ObjectId('62c68a888c6ba847ae6f7f5e'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 83,
#   'TRIP_DISTANCE': 0.87,
#   'PU_DO': '129_83',
#   'prediction': 10.133516712058306},
#  {'_id': ObjectId('62c68a898c6ba847ae6f7f5f'),
#   'PULOCATIONID': 205,
#   'DOLOCATIONID': 218,
#   'TRIP_DISTANCE': 1.21,
#   'PU_DO': '205_218',
#   'prediction': 7.517328156974742},
#  {'_id': ObjectId('62c68a8a8c6ba847ae6f7f60'),
#   'PULOCATIONID': 112,
#   'DOLOCATIONID': 256,
#   'TRIP_DISTANCE': 1.41,
#   'PU_DO': '112_256',
#   'prediction': 7.012693035555127},
#  {'_id': ObjectId('62c68a8b8c6ba847ae6f7f61'),
#   'PULOCATIONID': 80,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '80_264',
#   'prediction': 26.4375784155702},
#  {'_id': ObjectId('62c68a8c8c6ba847ae6f7f62'),
#   'PULOCATIONID': 256,
#   'DOLOCATIONID': 79,
#   'TRIP_DISTANCE': 2.35,
#   'PU_DO': '256_79',
#   'prediction': 18.069015050355553},
#  {'_id': ObjectId('62c68a8d8c6ba847ae6f7f63'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 2.43,
#   'PU_DO': '82_129',
#   'prediction': 10.349832956268443},
#  {'_id': ObjectId('62c68a8e8c6ba847ae6f7f64'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 83,
#   'TRIP_DISTANCE': 31.28,
#   'PU_DO': '129_83',
#   'prediction': 10.133516712058306},
#  {'_id': ObjectId('62c68a8f8c6ba847ae6f7f65'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 173,
#   'TRIP_DISTANCE': 1.31,
#   'PU_DO': '82_173',
#   'prediction': 12.65010601211562},
#  {'_id': ObjectId('62c68a908c6ba847ae6f7f66'),
#   'PULOCATIONID': 181,
#   'DOLOCATIONID': 228,
#   'TRIP_DISTANCE': 3.32,
#   'PU_DO': '181_228',
#   'prediction': 13.259396316030244},
#  {'_id': ObjectId('62c68a918c6ba847ae6f7f67'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 166,
#   'TRIP_DISTANCE': 0.17,
#   'PU_DO': '166_166',
#   'prediction': 4.9949303847116795},
#  {'_id': ObjectId('62c68a928c6ba847ae6f7f68'),
#   'PULOCATIONID': 197,
#   'DOLOCATIONID': 216,
#   'TRIP_DISTANCE': 0.36,
#   'PU_DO': '197_216',
#   'prediction': 9.090806744193753},
#  {'_id': ObjectId('62c68a938c6ba847ae6f7f69'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 0.9,
#   'PU_DO': '129_129',
#   'prediction': 6.9916633929227245},
#  {'_id': ObjectId('62c68a948c6ba847ae6f7f6a'),
#   'PULOCATIONID': 225,
#   'DOLOCATIONID': 198,
#   'TRIP_DISTANCE': 1.97,
#   'PU_DO': '225_198',
#   'prediction': 13.075582238896748},
#  {'_id': ObjectId('62c68a958c6ba847ae6f7f6b'),
#   'PULOCATIONID': 198,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 11.56,
#   'PU_DO': '198_129',
#   'prediction': 26.4375784155702},
#  {'_id': ObjectId('62c68a968c6ba847ae6f7f6c'),
#   'PULOCATIONID': 66,
#   'DOLOCATIONID': 65,
#   'TRIP_DISTANCE': 1.1,
#   'PU_DO': '66_65',
#   'prediction': 11.942995787937},
#  {'_id': ObjectId('62c68a978c6ba847ae6f7f6d'),
#   'PULOCATIONID': 166,
#   'DOLOCATIONID': 138,
#   'TRIP_DISTANCE': 8.22,
#   'PU_DO': '166_138',
#   'prediction': 26.790772032458694},
#  {'_id': ObjectId('62c68a988c6ba847ae6f7f6e'),
#   'PULOCATIONID': 159,
#   'DOLOCATIONID': 213,
#   'TRIP_DISTANCE': 5.09,
#   'PU_DO': '159_213',
#   'prediction': 15.948393395531246},
#  {'_id': ObjectId('62c68a998c6ba847ae6f7f6f'),
#   'PULOCATIONID': 145,
#   'DOLOCATIONID': 179,
#   'TRIP_DISTANCE': 1.65,
#   'PU_DO': '145_179',
#   'prediction': 14.07425166393033},
#  {'_id': ObjectId('62c68a9a8c6ba847ae6f7f70'),
#   'PULOCATIONID': 129,
#   'DOLOCATIONID': 93,
#   'TRIP_DISTANCE': 2.15,
#   'PU_DO': '129_93',
#   'prediction': 14.91659591012988},
#  {'_id': ObjectId('62c68a9b8c6ba847ae6f7f71'),
#   'PULOCATIONID': 169,
#   'DOLOCATIONID': 169,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '169_169',
#   'prediction': 6.4285966776507095},
#  {'_id': ObjectId('62c68a9c8c6ba847ae6f7f72'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 166,
#   'TRIP_DISTANCE': 0.62,
#   'PU_DO': '41_166',
#   'prediction': 6.440552795567935},
#  {'_id': ObjectId('62c68a9d8c6ba847ae6f7f73'),
#   'PULOCATIONID': 22,
#   'DOLOCATIONID': 22,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '22_22',
#   'prediction': 6.473034445415362},
#  {'_id': ObjectId('62c68a9e8c6ba847ae6f7f74'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 7,
#   'TRIP_DISTANCE': 0.67,
#   'PU_DO': '7_7',
#   'prediction': 6.062311597133295},
#  {'_id': ObjectId('62c68a9f8c6ba847ae6f7f75'),
#   'PULOCATIONID': 179,
#   'DOLOCATIONID': 179,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '179_179',
#   'prediction': 6.469898932547963},
#  {'_id': ObjectId('62c68aa08c6ba847ae6f7f76'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 141,
#   'TRIP_DISTANCE': 4.88,
#   'PU_DO': '255_141',
#   'prediction': 26.4375784155702},
#  {'_id': ObjectId('62c68aa18c6ba847ae6f7f77'),
#   'PULOCATIONID': 36,
#   'DOLOCATIONID': 255,
#   'TRIP_DISTANCE': 2.81,
#   'PU_DO': '36_255',
#   'prediction': 15.072961254413205},
#  {'_id': ObjectId('62c68aa28c6ba847ae6f7f78'),
#   'PULOCATIONID': 36,
#   'DOLOCATIONID': 209,
#   'TRIP_DISTANCE': 5.85,
#   'PU_DO': '36_209',
#   'prediction': 24.061062728777294},
#  {'_id': ObjectId('62c68aa38c6ba847ae6f7f79'),
#   'PULOCATIONID': 80,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '80_264',
#   'prediction': 26.4375784155702},
#  {'_id': ObjectId('62c68aa48c6ba847ae6f7f7a'),
#   'PULOCATIONID': 256,
#   'DOLOCATIONID': 167,
#   'TRIP_DISTANCE': 11.44,
#   'PU_DO': '256_167',
#   'prediction': 26.4375784155702},
#  {'_id': ObjectId('62c68aa58c6ba847ae6f7f7b'),
#   'PULOCATIONID': 7,
#   'DOLOCATIONID': 223,
#   'TRIP_DISTANCE': 2.08,
#   'PU_DO': '7_223',
#   'prediction': 9.539737443971482},
#  {'_id': ObjectId('62c68aa68c6ba847ae6f7f7c'),
#   'PULOCATIONID': 223,
#   'DOLOCATIONID': 179,
#   'TRIP_DISTANCE': 0.65,
#   'PU_DO': '223_179',
#   'prediction': 8.52399242781425},
#  {'_id': ObjectId('62c68aa78c6ba847ae6f7f7d'),
#   'PULOCATIONID': 179,
#   'DOLOCATIONID': 146,
#   'TRIP_DISTANCE': 1.67,
#   'PU_DO': '179_146',
#   'prediction': 6.234539546832959},
#  {'_id': ObjectId('62c68aa88c6ba847ae6f7f7e'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 264,
#   'TRIP_DISTANCE': 0.26,
#   'PU_DO': '95_264',
#   'prediction': 26.4375784155702},
#  {'_id': ObjectId('62c68aaa8c6ba847ae6f7f7f'),
#   'PULOCATIONID': 56,
#   'DOLOCATIONID': 56,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '56_56',
#   'prediction': 6.41057293813218},
#  {'_id': ObjectId('62c68aab8c6ba847ae6f7f80'),
#   'PULOCATIONID': 56,
#   'DOLOCATIONID': 56,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '56_56',
#   'prediction': 6.41057293813218},
#  {'_id': ObjectId('62c68aac8c6ba847ae6f7f81'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 1.0,
#   'PU_DO': '41_42',
#   'prediction': 6.757073235306535},
#  {'_id': ObjectId('62c68aad8c6ba847ae6f7f82'),
#   'PULOCATIONID': 33,
#   'DOLOCATIONID': 181,
#   'TRIP_DISTANCE': 1.98,
#   'PU_DO': '33_181',
#   'prediction': 17.388487656795235},
#  {'_id': ObjectId('62c68aae8c6ba847ae6f7f83'),
#   'PULOCATIONID': 18,
#   'DOLOCATIONID': 18,
#   'TRIP_DISTANCE': 0.21,
#   'PU_DO': '18_18',
#   'prediction': 10.32092914590634},
#  {'_id': ObjectId('62c68aaf8c6ba847ae6f7f84'),
#   'PULOCATIONID': 116,
#   'DOLOCATIONID': 42,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '116_42',
#   'prediction': 7.408748149877695},
#  {'_id': ObjectId('62c68ab08c6ba847ae6f7f85'),
#   'PULOCATIONID': 95,
#   'DOLOCATIONID': 130,
#   'TRIP_DISTANCE': 2.6,
#   'PU_DO': '95_130',
#   'prediction': 14.260813701264901},
#  {'_id': ObjectId('62c68ab18c6ba847ae6f7f86'),
#   'PULOCATIONID': 182,
#   'DOLOCATIONID': 159,
#   'TRIP_DISTANCE': 3.19,
#   'PU_DO': '182_159',
#   'prediction': 16.716298205183243},
#  {'_id': ObjectId('62c68ab28c6ba847ae6f7f87'),
#   'PULOCATIONID': 25,
#   'DOLOCATIONID': 25,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '25_25',
#   'prediction': 8.427396892738539},
#  {'_id': ObjectId('62c68ab38c6ba847ae6f7f88'),
#   'PULOCATIONID': 80,
#   'DOLOCATIONID': 255,
#   'TRIP_DISTANCE': 1.88,
#   'PU_DO': '80_255',
#   'prediction': 13.969783306565596},
#  {'_id': ObjectId('62c68ab48c6ba847ae6f7f89'),
#   'PULOCATIONID': 130,
#   'DOLOCATIONID': 139,
#   'TRIP_DISTANCE': 5.85,
#   'PU_DO': '130_139',
#   'prediction': 18.17230332598556},
#  {'_id': ObjectId('62c68ab58c6ba847ae6f7f8a'),
#   'PULOCATIONID': 82,
#   'DOLOCATIONID': 89,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '82_89',
#   'prediction': 33.814730442589145},
#  {'_id': ObjectId('62c68ab68c6ba847ae6f7f8b'),
#   'PULOCATIONID': 173,
#   'DOLOCATIONID': 129,
#   'TRIP_DISTANCE': 1.17,
#   'PU_DO': '173_129',
#   'prediction': 10.477830775450942},
#  {'_id': ObjectId('62c68ab78c6ba847ae6f7f8c'),
#   'PULOCATIONID': 75,
#   'DOLOCATIONID': 265,
#   'TRIP_DISTANCE': 27.97,
#   'PU_DO': '75_265',
#   'prediction': 29.355537435909362},
#  {'_id': ObjectId('62c68ab88c6ba847ae6f7f8d'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 127,
#   'TRIP_DISTANCE': 4.15,
#   'PU_DO': '41_127',
#   'prediction': 20.163429670180754},
#  {'_id': ObjectId('62c68ab98c6ba847ae6f7f8e'),
#   'PULOCATIONID': 116,
#   'DOLOCATIONID': 116,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '116_116',
#   'prediction': 5.549063637179447},
#  {'_id': ObjectId('62c68aba8c6ba847ae6f7f8f'),
#   'PULOCATIONID': 247,
#   'DOLOCATIONID': 247,
#   'TRIP_DISTANCE': 0.94,
#   'PU_DO': '247_247',
#   'prediction': 8.258667625930563},
#  {'_id': ObjectId('62c68abb8c6ba847ae6f7f90'),
#   'PULOCATIONID': 130,
#   'DOLOCATIONID': 218,
#   'TRIP_DISTANCE': 3.25,
#   'PU_DO': '130_218',
#   'prediction': 15.720330328754509},
#  {'_id': ObjectId('62c68abc8c6ba847ae6f7f91'),
#   'PULOCATIONID': 41,
#   'DOLOCATIONID': 75,
#   'TRIP_DISTANCE': 0.64,
#   'PU_DO': '41_75',
#   'prediction': 8.996568059328581},
#  {'_id': ObjectId('62c68abd8c6ba847ae6f7f92'),
#   'PULOCATIONID': 255,
#   'DOLOCATIONID': 80,
#   'TRIP_DISTANCE': 1.61,
#   'PU_DO': '255_80',
#   'prediction': 8.122089767414447},
#  {'_id': ObjectId('62c68abe8c6ba847ae6f7f93'),
#   'PULOCATIONID': 263,
#   'DOLOCATIONID': 140,
#   'TRIP_DISTANCE': 1.58,
#   'PU_DO': '263_140',
#   'prediction': 8.997704254778984},
#  {'_id': ObjectId('62c68abf8c6ba847ae6f7f94'),
#   'PULOCATIONID': 74,
#   'DOLOCATIONID': 75,
#   'TRIP_DISTANCE': 1.43,
#   'PU_DO': '74_75',
#   'prediction': 7.670144593030681},
#  {'_id': ObjectId('62c68ac08c6ba847ae6f7f95'),
#   'PULOCATIONID': 250,
#   'DOLOCATIONID': 250,
#   'TRIP_DISTANCE': 0.0,
#   'PU_DO': '250_250',
#   'prediction': 9.36841475769463},
#  {'_id': ObjectId('62c68ac18c6ba847ae6f7f96'),
#   'PULOCATIONID': 213,
#   'DOLOCATIONID': 250,
#   'TRIP_DISTANCE': 1.07,
#   'PU_DO': '213_250',
#   'prediction': 9.716923509577857},
#  ...]
